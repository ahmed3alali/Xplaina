# %%
import pandas as pd

coursera = pd.read_csv("Coursera.csv")
udemy = pd.read_csv("Udemy.csv")

# Make sure both have the same columns
common_cols = ['title', 'skills', 'rating', 'level', 'duration', 'instructor','description']
courses = pd.concat([coursera[common_cols], udemy[common_cols]], ignore_index=True)

courses.to_csv("courses.csv", index=False)

theCourses = pd.read_csv("courses.csv")
theCourses.tail()
# Out:
#                                                    title  \
# 27390                      Business English for Meetings
# 27391  Aerospace Engineering: Aircraft Systems and Av...
# 27392  Forensic Psychology : Criminal Profiling Certi...
# 27393  Deutsch Intensiv - Intensive German Course for...
# 27394       Renewable Energy and Sustainable Development
#
#                            skills  rating         level          duration  \
# 27390  General Programming Skills     4.6  Intermediate   1.5 total hours
# 27391                          Ai     4.4    All Levels   2.5 total hours
# 27392  General Programming Skills     4.4      Beginner     3 total hours
# 27393  General Programming Skills     4.8      Beginner  10.5 total hours
# 27394                          Ai     4.2      Beginner     2 total hours
#
#                       instructor  \
# 27390               Kendra Lucas
# 27391  Lluís Foreman - ValueKnow
# 27392            Ahilan Chandran
# 27393               Kamil Pakula
# 27394             Telly Frias Jr
#
#                                              description
# 27390  Useful English Phrases for Communicating with ...
# 27391  Aerospace and Aeronautical Engineering: Master...
# 27392                           Criminology Crash Course
# 27393  Master all the ins and outs of the German lang...
# 27394                               Environmental Issues
